# %%
import pandas as pd
import numpy as np

# %% [markdown]
# This module we'll be looking at the New York City tree census. This data was provided by a volunteer driven census in 2015, and we'll be accessing it via the socrata API. The main site for the data is [here](https://data.cityofnewyork.us/Environment/2015-Street-Tree-Census-Tree-Data/uvpi-gqnh), and on the upper right hand side you'll be able to see the link to the API.
#
# The data is conveniently available in json format, so we should be able to just read it directly in to Pandas:

# %%
url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json'
trees = pd.read_json(url)
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc status  \
# 0   180683    348711 2015-08-27         3           0          OnCurb  Alive
# 1   200540    315986 2015-09-03        21           0          OnCurb  Alive
# 2   204026    218365 2015-09-05         3           0          OnCurb  Alive
# 3   204337    217969 2015-09-05        10           0          OnCurb  Alive
# 4   189565    223043 2015-08-30        21           0          OnCurb  Alive
# 5   190422    106099 2015-08-30        11           0          OnCurb  Alive
# 6   190426    106099 2015-08-30        11           0          OnCurb  Alive
# 7   208649    103940 2015-09-07         9           0          OnCurb  Alive
# 8   209610    407443 2015-09-08         6           0          OnCurb  Alive
# 9   192755    207508 2015-08-31        21           0  OffsetFromCurb  Alive
#
#   health                           spc_latin        spc_common  ...  boro_ct  \
# 0   Fair                         Acer rubrum         red maple  ...  4073900
# 1   Fair                   Quercus palustris           pin oak  ...  4097300
# 2   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  3044900
# 3   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  3044900
# 4   Good                     Tilia americana   American linden  ...  3016500
# 5   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 6   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 7   Good                     Tilia americana   American linden  ...  1012700
# 8   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  5006400
# 9   Fair               Platanus x acerifolia  London planetree  ...  3037402
#
#       state   latitude  longitude          x_sp         y_sp council_district  \
# 0  New York  40.723092 -73.844215  1.027431e+06  202756.7687             29.0
# 1  New York  40.794111 -73.818679  1.034456e+06  228644.8374             19.0
# 2  New York  40.717581 -73.936608  1.001823e+06  200716.8913             34.0
# 3  New York  40.713537 -73.934456  1.002420e+06  199244.2531             34.0
# 4  New York  40.666778 -73.975979  9.909138e+05  182202.4260             39.0
# 5  New York  40.770046 -73.984950  9.884187e+05  219825.5227              3.0
# 6  New York  40.770210 -73.985338  9.883112e+05  219885.2785              3.0
# 7  New York  40.762724 -73.987297  9.877691e+05  217157.8561              3.0
# 8  New York  40.596579 -74.076255  9.630732e+05  156635.5542              NaN
# 9  New York  40.586357 -73.969744  9.926537e+05  152903.6306             47.0
#
#   census_tract        bin           bbl
# 0        739.0  4052307.0  4.022210e+09
# 1        973.0  4101931.0  4.044750e+09
# 2        449.0  3338310.0  3.028870e+09
# 3        449.0  3338342.0  3.029250e+09
# 4        165.0  3025654.0  3.010850e+09
# 5        145.0  1076229.0  1.011310e+09
# 6        145.0  1076229.0  1.011310e+09
# 7        133.0  1086093.0  1.010410e+09
# 8          NaN        NaN           NaN
# 9      37402.0  3320727.0  3.072350e+09
#
# [10 rows x 45 columns]

# %% [markdown]
# Looks good, but lets take a look at the shape of this data:

# %%
trees.shape
# Out:
# (1000, 45)

# %% [markdown]
# 1000 seems like too few trees for a city like New York, and a suspiciously round number. What's going on?
#
# Socrata places a 1000 row limit on their API. Raw data is meant to be "paged" through for applications, with the expectation that a UX wouldn't be able to handle a full dataset.
#
# As a simple example, if we had a mobile app with limited space that only displayed trees 5 at a time, we could view the first 5 trees in the dataset with the url below:

# %%
firstfive_url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json?$limit=5&$offset=0'
firstfive_trees = pd.read_json(firstfive_url)
firstfive_trees
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711 2015-08-27         3           0   OnCurb  Alive   Fair
# 1   200540    315986 2015-09-03        21           0   OnCurb  Alive   Fair
# 2   204026    218365 2015-09-05         3           0   OnCurb  Alive   Good
# 3   204337    217969 2015-09-05        10           0   OnCurb  Alive   Good
# 4   189565    223043 2015-08-30        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council_district  \
# 0  New York  40.723092 -73.844215  1027431.148  202756.7687               29
# 1  New York  40.794111 -73.818679  1034455.701  228644.8374               19
# 2  New York  40.717581 -73.936608  1001822.831  200716.8913               34
# 3  New York  40.713537 -73.934456  1002420.358  199244.2531               34
# 4  New York  40.666778 -73.975979   990913.775  182202.4260               39
#
#   census_tract      bin         bbl
# 0          739  4052307  4022210001
# 1          973  4101931  4044750045
# 2          449  3338310  3028870001
# 3          449  3338342  3029250001
# 4          165  3025654  3010850052
#
# [5 rows x 45 columns]

# %% [markdown]
# If we wanted the next 5, we would use this url:

# %%
nextfive_url = 'https://data.cityofnewyork.us/resource/nwxe-4ae8.json?$limit=5&$offset=5'
nextfive_trees = pd.read_json(nextfive_url)
nextfive_trees
# Out:
#    tree_id  block_id created_at  tree_dbh  stump_diam        curb_loc status  \
# 0   190422    106099 2015-08-30        11           0          OnCurb  Alive
# 1   190426    106099 2015-08-30        11           0          OnCurb  Alive
# 2   208649    103940 2015-09-07         9           0          OnCurb  Alive
# 3   209610    407443 2015-09-08         6           0          OnCurb  Alive
# 4   192755    207508 2015-08-31        21           0  OffsetFromCurb  Alive
#
#   health                           spc_latin        spc_common  ...  boro_ct  \
# 0   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 1   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  1014500
# 2   Good                     Tilia americana   American linden  ...  1012700
# 3   Good  Gleditsia triacanthos var. inermis       honeylocust  ...  5006400
# 4   Fair               Platanus x acerifolia  London planetree  ...  3037402
#
#       state   latitude  longitude         x_sp         y_sp council_district  \
# 0  New York  40.770046 -73.984950  988418.6997  219825.5227              3.0
# 1  New York  40.770210 -73.985338  988311.1900  219885.2785              3.0
# 2  New York  40.762724 -73.987297  987769.1163  217157.8561              3.0
# 3  New York  40.596579 -74.076255  963073.1998  156635.5542              NaN
# 4  New York  40.586357 -73.969744  992653.7253  152903.6306             47.0
#
#   census_tract        bin           bbl
# 0        145.0  1076229.0  1.011310e+09
# 1        145.0  1076229.0  1.011310e+09
# 2        133.0  1086093.0  1.010410e+09
# 3          NaN        NaN           NaN
# 4      37402.0  3320727.0  3.072350e+09
#
# [5 rows x 45 columns]

# %% [markdown]
# You can read more about paging using the Socrata API [here](https://dev.socrata.com/docs/paging.html)
#
# In these docs, you'll also see more advanced functions (called `SoQL`) under the "filtering and query" section. These functions should be reminding you of SQL.
#
# Think about the shape you want your data to be in before querying it. Using `SoQL` is a good way to avoid the limits of the API. For example, using the below query I can easily obtain the count of each species of tree in the Bronx:

# %%
boro = 'Bronx'
soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=spc_common,count(tree_id)' +\
        '&$where=boroname=\'Bronx\'' +\
        '&$group=spc_common').replace(' ', '%20')
soql_trees = pd.read_json(soql_url)

soql_trees
# Out:
#      count_tree_id           spc_common
# 0             4619                  NaN
# 1              662         silver maple
# 2               18       pagoda dogwood
# 3             3917    littleleaf linden
# 4               12       American larch
# ..             ...                  ...
# 128            362          sugar maple
# 129            170     Cornelian cherry
# 130            203            white oak
# 131             88  Kentucky yellowwood
# 132              6       European alder
#
# [133 rows x 2 columns]

# %% [markdown]
# This behavior is very common with web APIs, and I think this is useful when thinking about building interactive data products. When in a Jupyter Notebook or RStudio, there's an expectation that (unless you're dealing with truly large datasets) the data you want can be brought in memory and manipulated.
#
# Dash and Shiny abstract away the need to distinguish between client side and server side to make web development more accessible to data scientists. This can lead to some unintentional design mistakes if you don't think about how costly your callback functions are (for example: nothing will stop you in dash from running a costly model triggered whenever a dropdown is called.)
#
# The goal of using the Socrata is to force you to think about where your data operations are happening, and not resort to pulling in the data and performing all operations in local memory.
#
# ----------
#
# **NOTE**: One tip in dealing with URLs: you may need to replace spaces with `'%20'`. I personally just write out the url and then follow the string with a replace:

# %%
'https://api-url.com/?query with spaces'.replace(' ', '%20')
# Out:
# 'https://api-url.com/?query%20with%20spaces'

# %%
def format(itemlist):
    #i/p List  ["Bronx", "Queens" ]
    #o/p String : ("Bronx", "Queens")
    tmpList = ['\"' + str(elm) + '\"' for elm in itemlist]
    return '(' + ', ' .join(tmpList) + ')'

# %%
boroughs = ['Bronx', 'Queens']
species = ['sugar maple', 'silver maple']

soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=health , spc_common ,boroname ,count(tree_id)' +\
        '&$where=boroname in ' + format(boroughs) + ' and spc_common in ' + format(species) + ' ' +\
        '&$group=health,spc_common,boroname').replace(' ', '%20')
print(soql_url)
soql_trees = pd.read_json(soql_url)

soql_trees
# Out:
# https://data.cityofnewyork.us/resource/nwxe-4ae8.json?$select=health%20,%20spc_common%20,boroname%20,count(tree_id)&$where=boroname%20in%20("Bronx",%20"Queens")%20and%20spc_common%20in%20("sugar%20maple",%20"silver%20maple")%20&$group=health,spc_common,boroname
#    health    spc_common boroname  count_tree_id
# 0    Fair  silver maple    Bronx            102
# 1    Poor  silver maple   Queens            261
# 2    Good   sugar maple   Queens            874
# 3    Fair   sugar maple   Queens            286
# 4    Good  silver maple    Bronx            522
# 5    Poor   sugar maple    Bronx             30
# 6    Good  silver maple   Queens           4695
# 7    Poor   sugar maple   Queens            122
# 8    Fair   sugar maple    Bronx             69
# 9    Poor  silver maple    Bronx             38
# 10   Good   sugar maple    Bronx            263
# 11   Fair  silver maple   Queens           1160

# %%
soql_trees['boroname_and_species'] = soql_trees['boroname'] + ',' + soql_trees['spc_common']
print(soql_trees)
# Out:
#    health    spc_common boroname  count_tree_id boroname_and_species
# 0    Fair  silver maple    Bronx            102   Bronx,silver maple
# 1    Poor  silver maple   Queens            261  Queens,silver maple
# 2    Good   sugar maple   Queens            874   Queens,sugar maple
# 3    Fair   sugar maple   Queens            286   Queens,sugar maple
# 4    Good  silver maple    Bronx            522   Bronx,silver maple
# 5    Poor   sugar maple    Bronx             30    Bronx,sugar maple
# 6    Good  silver maple   Queens           4695  Queens,silver maple
# 7    Poor   sugar maple   Queens            122   Queens,sugar maple
# 8    Fair   sugar maple    Bronx             69    Bronx,sugar maple
# 9    Poor  silver maple    Bronx             38   Bronx,silver maple
# 10   Good   sugar maple    Bronx            263    Bronx,sugar maple
# 11   Fair  silver maple   Queens           1160  Queens,silver maple

# %%
soql_trees = soql_trees.drop(columns=['spc_common', 'boroname'])

# %%
print(soql_trees)
# Out:
#    health  count_tree_id boroname_and_species
# 0    Fair            102   Bronx,silver maple
# 1    Poor            261  Queens,silver maple
# 2    Good            874   Queens,sugar maple
# 3    Fair            286   Queens,sugar maple
# 4    Good            522   Bronx,silver maple
# 5    Poor             30    Bronx,sugar maple
# 6    Good           4695  Queens,silver maple
# 7    Poor            122   Queens,sugar maple
# 8    Fair             69    Bronx,sugar maple
# 9    Poor             38   Bronx,silver maple
# 10   Good            263    Bronx,sugar maple
# 11   Fair           1160  Queens,silver maple

# %%
soql_trees['health_ratio'] = soql_trees.groupby(['boroname_and_species'])['count_tree_id'].transform(lambda x: x/x.sum()*100)

# %%
print(soql_trees)
# Out:
#    health  count_tree_id boroname_and_species
# 0    Fair            102   Bronx,silver maple
# 1    Poor            261  Queens,silver maple
# 2    Good            874   Queens,sugar maple
# 3    Fair            286   Queens,sugar maple
# 4    Good            522   Bronx,silver maple
# 5    Poor             30    Bronx,sugar maple
# 6    Good           4695  Queens,silver maple
# 7    Poor            122   Queens,sugar maple
# 8    Fair             69    Bronx,sugar maple
# 9    Poor             38   Bronx,silver maple
# 10   Good            263    Bronx,sugar maple
# 11   Fair           1160  Queens,silver maple

# %%
soql_treesgroupBy = soql_trees.sort_values(['boroname_and_species'], ascending=[True])
print(soql_treesgroupBy)
# Out:
#    health  count_tree_id boroname_and_species  health_ratio
# 0    Fair            102   Bronx,silver maple     15.407855
# 4    Good            522   Bronx,silver maple     78.851964
# 9    Poor             38   Bronx,silver maple      5.740181
# 5    Poor             30    Bronx,sugar maple      8.287293
# 8    Fair             69    Bronx,sugar maple     19.060773
# 10   Good            263    Bronx,sugar maple     72.651934
# 1    Poor            261  Queens,silver maple      4.267495
# 6    Good           4695  Queens,silver maple     76.765860
# 11   Fair           1160  Queens,silver maple     18.966645
# 2    Good            874   Queens,sugar maple     68.174727
# 3    Fair            286   Queens,sugar maple     22.308892
# 7    Poor            122   Queens,sugar maple      9.516381

# %%
boro = 'Bronx'

soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=distinct(boroname)')
boroughs = pd.read_json(soql_url)
# Out:
#       boroname_1
# 0       Brooklyn
# 1      Manhattan
# 2         Queens
# 3          Bronx
# 4  Staten Island

# %%
boroughs[0:2]['boroname_1']
# Out:
# 0     Brooklyn
# 1    Manhattan
# Name: boroname_1, dtype: object

# %%
soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=distinct(spc_common)')
spc_common = pd.read_json(soql_url)

spc_common
# Out:
#             spc_common_1
# 0                    NaN
# 1           silver maple
# 2         pagoda dogwood
# 3      littleleaf linden
# 4         American larch
# ..                   ...
# 128          sugar maple
# 129     Cornelian cherry
# 130            white oak
# 131  Kentucky yellowwood
# 132       European alder
#
# [133 rows x 1 columns]

# %%
soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=distinct(steward)')
steward = pd.read_json(soql_url)

steward
# Out:
#   steward_1
# 0      3or4
# 1       NaN
# 2   4orMore
# 3      1or2
# 4      None

# %%
if ((len(boroughs)>0) & (len(species) < 0)):
    print("s")
else:
    print("w")
# Out:
# w

# %%
trees['steward']
trees.dr
# Out:
# 0      None
# 1      None
# 2      1or2
# 3      None
# 4      None
#        ...
# 995    1or2
# 996    None
# 997    None
# 998    None
# 999    None
# Name: steward, Length: 1000, dtype: object

# %%
soql_url = ('https://data.cityofnewyork.us/resource/nwxe-4ae8.json?' +\
        '$select=*' +\
        '&$where=health  is not null &$limit=80000').replace(' ', '%20')
treesall = pd.read_json(soql_url)

treesall.shape[0]
# Out:
# 80000

# %%
#trees = treesall[(treesall['steward'] != "None") & (treesall['health'] != "None")]
treesall['BiVariateCatg'] = treesall['steward'].astype(str) + '|' +  treesall['health'].astype(str)

treesall['BiVariateCatg'] = pd.Categorical(trees['BiVariateCatg'])


treesall.head()
# Out:
# C:\Users\Charls\Anaconda3\envs\data608\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Charls\Anaconda3\envs\data608\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     tree_id  block_id created_at  tree_dbh  stump_diam curb_loc status health  \
# 2    204026    218365 2015-09-05         3           0   OnCurb  Alive   Good
# 5    190422    106099 2015-08-30        11           0   OnCurb  Alive   Good
# 6    190426    106099 2015-08-30        11           0   OnCurb  Alive   Good
# 13   189465    219493 2015-08-30        22           0   OnCurb  Alive   Good
# 14   192998    211160 2015-08-31        30           0   OnCurb  Alive   Fair
#
#                              spc_latin        spc_common  ...     state  \
# 2   Gleditsia triacanthos var. inermis       honeylocust  ...  New York
# 5   Gleditsia triacanthos var. inermis       honeylocust  ...  New York
# 6   Gleditsia triacanthos var. inermis       honeylocust  ...  New York
# 13               Platanus x acerifolia  London planetree  ...  New York
# 14               Platanus x acerifolia  London planetree  ...  New York
#
#      latitude  longitude          x_sp         y_sp council_district  \
# 2   40.717581 -73.936608  1.001823e+06  200716.8913             34.0
# 5   40.770046 -73.984950  9.884187e+05  219825.5227              3.0
# 6   40.770210 -73.985338  9.883112e+05  219885.2785              3.0
# 13  40.694733 -73.968211  9.930653e+05  192388.0651             35.0
# 14  40.664317 -73.921130  1.006131e+06  181314.9855             41.0
#
#    census_tract        bin           bbl BiVariateCatg
# 2         449.0  3338310.0  3.028870e+09     1or2|Good
# 5         145.0  1076229.0  1.011310e+09     1or2|Good
# 6         145.0  1076229.0  1.011310e+09     1or2|Good
# 13        191.0  3054331.0  3.018880e+09     3or4|Good
# 14        900.0  3081177.0  3.035310e+09     1or2|Fair
#
# [5 rows x 46 columns]

# %%
treesall['BiVariateCatg'].unique()
# Out:
# [None|Fair, 1or2|Good, None|Good, None|Poor, 3or4|Good, ..., 3or4|Fair, 1or2|Poor, 4orMore|Good, 4orMore|Fair, 4orMore|Poor]
# Length: 12
# Categories (12, object): [None|Fair, 1or2|Good, None|Good, None|Poor, ..., 1or2|Poor, 4orMore|Good, 4orMore|Fair, 4orMore|Poor]

# %%
trees.shape
# Out:
# (24437, 46)

# %%
treesall['BiVariateCatg'] = treesall['steward'].astype(str) + '|' +  treesall['health'].astype(str)

treesall['BiVariateCatg'] = pd.Categorical(treesall['BiVariateCatg'])

# %%
import datashader as ds
import datashader.transfer_functions as tf
import datashader.glyphs
from datashader import reductions
from datashader.core import bypixel
from datashader.utils import lnglat_to_meters as webm, export_image
from datashader.colors import colormap_select, Greys9, viridis, inferno
from functools import partial
#Defining some helper functions for DataShader
background = "black"
export = partial(export_image, background = background, export_path="export")
cm = partial(colormap_select, reverse=(background!="black"))

# %%
colorscale_seq = {'None|Poor' : "#543005", 'None|Good' : "#8c510a", 'None|Fair' : "#bf812d",
              '1or2|Poor' : "#dfc27d", '1or2|Good' : "#f6e8c3", '1or2|Fair' : "#f5f5f5", 
              '3or4|Poor' :"#c7eae5",'3or4|Good' : "#c7eae5", '3or4|Fair': "#80cdc1", 
              '4orMore|Poor' : "#35978f",'4orMore|Good' : "#01665e", '4orMore|Fair' : "#003c30"
             }

colorscale_df = { 'None|Good' : "#2ca25f", 'None|Fair' : "#99d8c9" , 'None|Poor' : "#e5f5f9" ,
              '1or2|Good' : "#b7a96b", '1or2|Fair' : "#fdcc8a", '1or2|Poor' : "#d7b5d8", 
              '3or4|Good' :"#fc8d59",'3or4|Fair' : "#EE7985", '3or4|Poor': "#df65b0", 
              '4orMore|Good' : "#d7301f",'4orMore|Fair' : "#D3213B", '4orMore|Poor' : "#ce1256"
             }

colorscale_new = { 'None|Good' : "#2ca25f", 'None|Fair' : "#99d8c9" , 'None|Poor' : "#e5f5f9" ,
              '1or2|Good' : "#cc4c02", '1or2|Fair' : "#b8c7d1", '1or2|Poor' : "#d7b5d8", 
              '3or4|Good' :"#868388",'3or4|Fair' : "#bc9fbd", '3or4|Poor': "#df65b0", 
              '4orMore|Good' : "#7d5a5a",'4orMore|Fair' : "#b47590", '4orMore|Poor' : "#ce1256"
             }

colorscale_new1 = { 'None|Good' : "#e5f5f9", 'None|Fair' : "#e5f5f9" , 'None|Poor' : "#f7fcfd" ,
              '1or2|Good' : "#41ae76", '1or2|Fair' : "#66c2a4", '1or2|Poor' : "#e5f5f9", 
              '3or4|Good' :"#238b45",'3or4|Fair' : "#006d2c", '3or4|Poor': "#e5f5f9", 
              '4orMore|Good' : "#00441b",'4orMore|Fair' : "#00441b", '4orMore|Poor' : "#e5f5f9"
             }




#['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#f5f5f5','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
NewYorkCity   = (( -74.29,  -73.69), (40.49, 40.92))
cvs = ds.Canvas(500, 500, *NewYorkCity)
ds.count_cat('BiVariateCatg')
agg = cvs.points(treesall, 'longitude', 'latitude', ds.count_cat('BiVariateCatg'))
view = tf.shade(agg, color_key = colorscale_new1)

export(tf.spread(view, px=1), 'choropleth')
# Out:
# <xarray.Image (latitude: 500, longitude: 500)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * latitude   (latitude) float64 -74.29 -74.29 -74.29 ... -73.69 -73.69 -73.69
#   * longitude  (longitude) float64 40.49 40.49 40.49 40.49 ... 40.92 40.92 40.92

# %%
trees = treesall[(treesall['steward'] != "None") & (treesall['health'] != "None")]

colorscale_seq = {'None|Poor' : "#543005", 'None|Good' : "#8c510a", 'None|Fair' : "#bf812d",
              '1or2|Poor' : "#dfc27d", '1or2|Good' : "#f6e8c3", '1or2|Fair' : "#f5f5f5", 
              '3or4|Poor' :"#c7eae5",'3or4|Good' : "#c7eae5", '3or4|Fair': "#80cdc1", 
              '4orMore|Poor' : "#35978f",'4orMore|Good' : "#01665e", '4orMore|Fair' : "#003c30"
             }

colorscale_df = { 'None|Good' : "#2ca25f", 'None|Fair' : "#99d8c9" , 'None|Poor' : "#e5f5f9" ,
              '1or2|Good' : "#b7a96b", '1or2|Fair' : "#fdcc8a", '1or2|Poor' : "#d7b5d8", 
              '3or4|Good' :"#fc8d59",'3or4|Fair' : "#EE7985", '3or4|Poor': "#df65b0", 
              '4orMore|Good' : "#d7301f",'4orMore|Fair' : "#D3213B", '4orMore|Poor' : "#ce1256"
             }

colorscale_new = { 'None|Good' : "#2ca25f", 'None|Fair' : "#99d8c9" , 'None|Poor' : "#e5f5f9" ,
              '1or2|Good' : "#cc4c02", '1or2|Fair' : "#b8c7d1", '1or2|Poor' : "#d7b5d8", 
              '3or4|Good' :"#868388",'3or4|Fair' : "#bc9fbd", '3or4|Poor': "#df65b0", 
              '4orMore|Good' : "#7d5a5a",'4orMore|Fair' : "#b47590", '4orMore|Poor' : "#ce1256"
             }

colorscale_new1 = { 'None|Good' : "#e5f5f9", 'None|Fair' : "#e5f5f9" , 'None|Poor' : "#f7fcfd" ,
              '1or2|Good' : "#41ae76", '1or2|Fair' : "#66c2a4", '1or2|Poor' : "#e5f5f9", 
              '3or4|Good' :"#238b45",'3or4|Fair' : "#006d2c", '3or4|Poor': "#e5f5f9", 
              '4orMore|Good' : "#00441b",'4orMore|Fair' : "#00441b", '4orMore|Poor' : "#e5f5f9"
             }




#['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#f5f5f5','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
NewYorkCity   = (( -74.29,  -73.69), (40.49, 40.92))
cvs = ds.Canvas(500, 500, *NewYorkCity)
ds.count_cat('BiVariateCatg')
agg = cvs.points(trees, 'longitude', 'latitude', ds.count_cat('BiVariateCatg'))
view = tf.shade(agg, color_key = colorscale_new1)

export(tf.spread(view, px=1), 'choropleth')
# Out:
# <xarray.Image (latitude: 500, longitude: 500)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * latitude   (latitude) float64 -74.29 -74.29 -74.29 ... -73.69 -73.69 -73.69
#   * longitude  (longitude) float64 40.49 40.49 40.49 40.49 ... 40.92 40.92 40.92

# %%
from bokeh.plotting import figure, output_file, show
from datashader.bokeh_ext import create_ramp_legend, create_categorical_legend
from bokeh.palettes import Viridis256 as palette
how = 'log'


import bokeh.plotting
bokeh.plotting.output_notebook()

height = 600
width = 600

#show(create_categorical_legend(colorscale))

bokeh.plotting.show(create_categorical_legend(colorscale_new1))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a47115ec-1bc6-4de3-87a8-1a058ae3ec57" data-root-id="1004"></div>

# %%
import researchpy as rp
table, results = rp.crosstab(trees['steward'], trees['health'], prop= 'col', test= 'chi-square')
table.reset_index()
table
# Out:
#          health
#            Fair    Good    Poor     All
# steward
# 1or2      85.43   83.20   85.64   83.75
# 3or4      13.83   15.55   13.82   15.14
# 4orMore    0.75    1.24    0.54    1.11
# All      100.00  100.00  100.00  100.00

# %%
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 6.0) =   34.6580
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0147

# %%
import researchpy as rp
trees_si = trees[trees['boroname'] == 'Staten Island']
trees_mn = trees[trees['boroname'] == 'Manhattan']
trees_qn = trees[trees['boroname'] == 'Queens']
trees_bx = trees[trees['boroname'] == 'Bronx']
trees_bk = trees[trees['boroname'] == 'Brooklyn']

#Staten Island
table, results = rp.crosstab(trees_si['steward'], trees_si['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =    7.9637
# 1                    p-value =    0.0929
# 2                 Cramer's V =    0.0445

# %%
#Manhatten
table, results = rp.crosstab(trees_mn['steward'], trees_mn['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =    8.4633
# 1                    p-value =    0.0760
# 2                 Cramer's V =    0.0236

# %%
trees_mn_count = trees_mn.groupby(["steward", "health" ]).tree_id.agg(['count']).reset_index()
trees_mn_count
# Out:
#    steward health  count
# 0     1or2   Fair   1015
# 1     1or2   Good   4122
# 2     1or2   Poor    417
# 3     3or4   Fair    358
# 4     3or4   Good   1409
# 5     3or4   Poor    131
# 6  4orMore   Fair     24
# 7  4orMore   Good    123
# 8  4orMore   Poor      3

# %%
trees_mn_sum = trees_mn_count.groupby(["steward"])['count'].agg(['sum'])

trees_mn_sum
# Out:
#           sum
# steward
# 1or2     5554
# 3or4     1898
# 4orMore   150

# %% [raw]
# df_merge_col = pd.merge(trees_mn_sum, trees_mn_count, on='steward', how='inner')

# %%
df_merge_col
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7b38ac365339> in <module>
# ----> 1 df_merge_col
#
# NameError: name 'df_merge_col' is not defined

# %%
trees_mn_count
# Out:
#    steward health  count
# 0     1or2   Fair   1015
# 1     1or2   Good   4122
# 2     1or2   Poor    417
# 3     3or4   Fair    358
# 4     3or4   Good   1409
# 5     3or4   Poor    131
# 6  4orMore   Fair     24
# 7  4orMore   Good    123
# 8  4orMore   Poor      3

# %%
df_merge_col['prop'] = df_merge_col.apply(lambda row: row.count, axis=1)

# %%
df_merge_col
# Out:
#    steward   sum health  count  \
# 0     1or2  5554   Fair   1015
# 1     1or2  5554   Good   4122
# 2     1or2  5554   Poor    417
# 3     3or4  1898   Fair    358
# 4     3or4  1898   Good   1409
# 5     3or4  1898   Poor    131
# 6  4orMore   150   Fair     24
# 7  4orMore   150   Good    123
# 8  4orMore   150   Poor      3
#
#                                                 prop
# 0  <bound method Series.count of steward    None\...
# 1  <bound method Series.count of steward    None\...
# 2  <bound method Series.count of steward    None\...
# 3  <bound method Series.count of steward    None\...
# 4  <bound method Series.count of steward    None\...
# 5  <bound method Series.count of steward    None\...
# 6  <bound method Series.count of steward    None\...
# 7  <bound method Series.count of steward    None\...
# 8  <bound method Series.count of steward    None\...

# %%
table
# Out:
#          health
#            Fair    Good    Poor     All
# steward
# 1or2      72.66   72.90   75.68   73.06
# 3or4      25.63   24.92   23.77   24.97
# 4orMore    1.72    2.18    0.54    1.97
# All      100.00  100.00  100.00  100.00

# %%
#Queens
table, results = rp.crosstab(trees_qn['steward'], trees_qn['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =   14.0359
# 1                    p-value =    0.0072
# 2                 Cramer's V =    0.0346

# %%
table
# Out:
#          health
#            Fair    Good    Poor     All
# steward
# 1or2      92.52   89.43   92.26   90.17
# 3or4       7.12    9.88    6.55    9.17
# 4orMore    0.36    0.70    1.19    0.66
# All      100.00  100.00  100.00  100.00

# %%
#Bronx
table, results = rp.crosstab(trees_bx['steward'], trees_bx['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =    4.6069
# 1                    p-value =    0.3301
# 2                 Cramer's V =    0.0357

# %%
#trees_bk
table, results = rp.crosstab(trees_bk['steward'], trees_bk['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 4.0) =   31.3054
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0468

# %%
#All
table, results = rp.crosstab(treesall['steward'], treesall['health'], prop= 'col', test= 'chi-square')
    
results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 6.0) =   34.6580
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0147

# %%
table
# Out:
#          health
#            Fair    Good    Poor     All
# steward
# 1or2      25.58   25.42   27.80   25.58
# 3or4       4.14    4.75    4.49    4.62
# 4orMore    0.22    0.38    0.18    0.34
# None      70.05   69.45   67.53   69.45
# All      100.00  100.00  100.00  100.00

# %%
#All
table, results = rp.crosstab(trees['steward'], trees['health'], prop= 'col', test= 'chi-square')
results
table
# Out:
#          health
#            Fair    Good    Poor     All
# steward
# 1or2      85.43   83.20   85.64   83.75
# 3or4      13.83   15.55   13.82   15.14
# 4orMore    0.75    1.24    0.54    1.11
# All      100.00  100.00  100.00  100.00
